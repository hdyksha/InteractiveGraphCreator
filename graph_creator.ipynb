# %%
  import warnings
  warnings.filterwarnings('ignore')

# %%
# %matplotlib inline
from graph_manager import *

# %%
gm = GraphManager()
gm.file = "https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv"
gm.manage_graph_drawer()
# Out:
# --------------------------------------------------
# please select a number of a plot type
#     0: scatter
#     1: point
#     2: bar
#     3: dist
#     4: box
#     5: count
#     6: joint
#     7: strip
#     8: pair
#     9: percentile
# input(plot type): 6
# JointPlotDrawer starts drawing a graph
# reading the csv file
# --------------------------------------------------
# please select column(s) to be used as axises
#     0: sepal_length
#     1: sepal_width
#     2: petal_length
#     3: petal_width
#     4: species
# input(x): 0
# input(y): 1
# The plot is saved as iris.png

# %%
gm = GraphManager()
gm.file = "https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv"
gm.plot_type = "point"
gm.arg_dict["outfile"] = "output.eps"
gm.arg_dict["x"] = "petal_length"
gm.arg_dict["hue"] = "?"
gm.manage_graph_drawer()
# Out:
# PointPlotDrawer starts drawing a graph
# reading the csv file
# --------------------------------------------------
# please select column(s) to be used as axises
#     0: sepal_length
#     1: sepal_width
#     2: petal_length
#     3: petal_width
#     4: species
# input(y): 3
# input(hue): 4
# The plot is saved as output.eps

# %%
gm = GraphManager()
gm.file = "https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv"
gm.plot_type = "box"
gm.arg_dict["x"] = "sepal_length"
gm.arg_dict["y"] = "petal_length"
gm.arg_dict["hue"] = "species"
gm.arg_dict["xlabel"] = "xlabel"
gm.arg_dict["ylabel"] = "ylabel"
gm.arg_dict["title"] = "title"
gm.arg_dict["context"] = "?"
gm.manage_graph_drawer()
# Out:
# BoxPlotDrawer starts drawing a graph
# reading the csv file
# --------------------------------------------------
# please select column(s) to be used as axises
#     0: sepal_length
#     1: sepal_width
#     2: petal_length
#     3: petal_width
#     4: species
# --------------------------------------------------
# please select a context parameter
#     0: paper
#     1: notebook
#     2: talk
#     3: poster
# input(context): 3
# The plot is saved as iris.png

# %%
gm = GraphManager()
gm.file = "https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv"
gm.plot_type = "percentile"
gm.arg_dict["x"] = "sepal_length"
gm.arg_dict["y"] = "petal_length"
gm.arg_dict["hue"] = "species"
gm.arg_dict["context"] = "notebook"
gm.arg_dict["style"] = "?"
gm.arg_dict["palette"] = "?"
gm.manage_graph_drawer()
# Out:
# PercentilePlotDrawer starts drawing a graph
# reading the csv file
# --------------------------------------------------
# please select column(s) to be used as axises
#     0: sepal_length
#     1: sepal_width
#     2: petal_length
#     3: petal_width
#     4: species
# --------------------------------------------------
# please select a style parameter
#     0: darkgrid
#     1: whitegrid
#     2: dark
#     3: white
#     4: ticks
# input(style): 4
# --------------------------------------------------
# please select a palette parameter
#     0: deep
#     1: muted
#     2: pastel
#     3: bright
#     4: dark
#     5: colorblind
# input(palette): 5
# The plot is saved as iris.png
